# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Model Training

# %%
df=pd.read_csv('diamonds.csv')



df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df.columns.str.match("Unnamed")
df=df.drop("Unnamed: 0",axis=1)

# %%
X=df.drop("price",axis=1)    #seggregating independent features and dependent features
Y=df[['price']]

# %%
X
# Out:
#        carat        cut color clarity  depth  table     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0  5.83  5.87  3.64
#
# [53940 rows x 9 columns]

# %%
Y
# Out:
#        price
# 0        326
# 1        326
# 2        327
# 3        334
# 4        335
# ...      ...
# 53935   2757
# 53936   2757
# 53937   2757
# 53938   2757
# 53939   2757
#
# [53940 rows x 1 columns]

# %%
#defining which columns should be ordinal encoded and which should be 
categoricals=X.select_dtypes(include='object').columns
numericals=X.select_dtypes(exclude='object').columns

# %%
numericals
# Out:
# Index(['carat', 'depth', 'table', 'x', 'y', 'z'], dtype='object')

# %%
#defining the custom  ranking from high to low of each ordinal feature
cut_categories=['Fair','Good','Very Good','Premium','Ideal']
clarity_categories=['I1','SI2','SI1','VS2','VS1','VVS2','VVS1','IF']
color_categories=['D','E','F','G','H','I','J']

# %%
from sklearn.impute import SimpleImputer #for handling the misssing values 
from sklearn.preprocessing import StandardScaler# for feature scaling
from sklearn.preprocessing import OrdinalEncoder #for ordinal encoding to categorical variables.

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
#numerical pipeline
num_pipeline=Pipeline(
    steps=[
        ('imputer for handling missing values',SimpleImputer(strategy='median')),
        ('scaler for feature scaling',StandardScaler())
    ]
)

## for categorical feature
categorical_pipeline=Pipeline(
    steps=[
        ('imputer for handling the missing values' ,SimpleImputer(strategy='most_frequent')),
        ('ordinal enoding',OrdinalEncoder(categories=[cut_categories,clarity_categories,color_categories])),
        ('scaler',StandardScaler())
    ]
)

preprocessor=ColumnTransformer([
    ('num_pipeline',num_pipeline,numericals),
    ('categorical_pipelines',categorical_pipeline,categoricals)
])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.3,random_state=33)

# %%
X_train=pd.DataFrame(preprocessor.fit_transform(X_train),columns=preprocessor.get_feature_names_out())
X_test=pd.DataFrame(preprocessor.transform(X_test),columns=preprocessor.get_feature_names_out())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 X_train=pd.DataFrame(preprocessor.fit_transform(X_train),columns=preprocessor.get_feature_names_out())
#       2 X_test=pd.DataFrame(preprocessor.transform(X_test),columns=preprocessor.get_feature_names_out())
#
# File ~/.local/lib/python3.8/site-packages/sklearn/utils/_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return_tuple = (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 preprocessor.get_feature_names_out()
#
# File ~/.local/lib/python3.8/site-packages/sklearn/compose/_column_transformer.py:522, in ColumnTransformer.get_feature_names_out(self, input_features)
#     520 # List of tuples (name, feature_names_out)
#     521 transformer_with_feature_names_out = []
# --> 522 for name, trans, column, _ in self._iter(fitted=True):
#     523     feature_names_out = self._get_feature_name_out_for_transformer(
#     524         name, trans, column, input_features
#     525     )
#     526     if feature_names_out is None:
#
# File ~/.local/lib/python3.8/site-packages/sklearn/compose/_column_transformer.py:374, in ColumnTransformer._iter(self, fitted, replace_strings, column_as_strings)
#     370         transformers = [
# ...

# %%
X_train
# Out:
#        carat        cut color clarity  depth  table     x     y     z
# 30634   0.34      Ideal     G    VVS2   62.0   56.0  4.46  4.48  2.77
# 17601   1.33      Ideal     H     SI1   62.7   56.0  6.99  7.04  4.40
# 10590   0.91  Very Good     E     VS2   62.9   55.0  6.13  6.17  3.87
# 53663   0.80  Very Good     D     SI2   63.7   57.0  5.87  5.90  3.75
# 6235    0.90       Good     F     SI1   62.6   58.0  6.10  6.14  3.83
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...
# 27282   2.01  Very Good     I     VS1   59.7   63.0  8.24  8.15  4.89
# 578     0.53      Ideal     F    VVS1   61.4   57.0  5.20  5.23  3.20
# 38616   0.30      Ideal     J      IF   61.5   56.0  4.32  4.33  2.66
# 2439    0.70      Ideal     H     VS1   61.0   56.0  5.75  5.79  3.51
# 23572   1.28      Ideal     F     VS1   61.7   55.0  7.01  6.98  4.32
#
# [37758 rows x 9 columns]

# %%
#preprocessor.fit_transform(X_train)
from sklearn.linear_model  import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.metrics  import r2_score,mean_absolute_error,mean_squared_error

# %%
regression=LinearRegression()
regression.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_911/3677649706.py in ?()
# ----> 2 regression=LinearRegression()
#       3 regression.fit(X_train,y_train)
#
# ~/.local/lib/python3.8/site-packages/sklearn/base.py in ?(estimator, *args, **kwargs)
#    1147                 skip_parameter_validation=(
#    1148                     prefer_skip_nested_validation or global_skip_validation
#    1149                 )
#    1150             ):
# -> 1151                 return fit_method(estimator, *args, **kwargs)
#
# ~/.local/lib/python3.8/site-packages/sklearn/linear_model/_base.py in ?(self, X, y, sample_weight)
#     674         n_jobs_ = self.n_jobs
#     675
#     676         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     677
# --> 678         X, y = self._validate_data(
# ...

# %%
#X_train=preprocessor.fit_transform(X_train)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'price'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
X_train
# Out:
#        carat        cut color clarity  depth  table     x     y     z
# 30634   0.34      Ideal     G    VVS2   62.0   56.0  4.46  4.48  2.77
# 17601   1.33      Ideal     H     SI1   62.7   56.0  6.99  7.04  4.40
# 10590   0.91  Very Good     E     VS2   62.9   55.0  6.13  6.17  3.87
# 53663   0.80  Very Good     D     SI2   63.7   57.0  5.87  5.90  3.75
# 6235    0.90       Good     F     SI1   62.6   58.0  6.10  6.14  3.83
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...
# 27282   2.01  Very Good     I     VS1   59.7   63.0  8.24  8.15  4.89
# 578     0.53      Ideal     F    VVS1   61.4   57.0  5.20  5.23  3.20
# 38616   0.30      Ideal     J      IF   61.5   56.0  4.32  4.33  2.66
# 2439    0.70      Ideal     H     VS1   61.0   56.0  5.75  5.79  3.51
# 23572   1.28      Ideal     F     VS1   61.7   55.0  7.01  6.98  4.32
#
# [37758 rows x 9 columns]
